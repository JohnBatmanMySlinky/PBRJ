# %%
include("../RayTracing.jl")
# Out:
# Main.RayTracing

# %%
ccw_90 = RayTracing.UVMapping2DFull_rotate_90_ccw()
# Out:
# Main.RayTracing.UVMapping2DFull(0.0, -1.0, 1.0, 0.0, 1.0, 0.0)

# %%
si = RayTracing.empty_surface_interation()
si.uv = RayTracing.Pnt2(0.5, 0.5)
st, _, _ = ccw_90(si)
st
# Out:
# 2-element Main.RayTracing.Pnt2 with indices SOneTo(2):
#  0.5
#  0.5

# %%
si = RayTracing.empty_surface_interation()
si.uv = RayTracing.Pnt2(0.025, 0.0)
st, _, _ = ccw_90(si)
st
# Out:
# 2-element Main.RayTracing.Pnt2 with indices SOneTo(2):
#  1.0
#  0.025
