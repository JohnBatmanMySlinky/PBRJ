# %%
include("../RayTracing.jl")
# Out:
# Main.RayTracing

# %%
s = RayTracing.Spectrum(0.0177, 0.0412, 0.1356)
# Out:
# 3-element Main.RayTracing.Spectrum with indices SOneTo(3):
#  0.0177
#  0.0412
#  0.1356

# %%
x = RayTracing.RGB_to_XYZ(s)
# Out:
# 3-element Main.RayTracing.XYZPBRT with indices SOneTo(3):
#  0.046498072900000006
#  0.0430149851
#  0.13410374460000002

# %%
r = RayTracing.XYZ_to_RGB(x)
# Out:
# 3-element Main.RayTracing.RGBPBRT with indices SOneTo(3):
#  0.017700134112293125
#  0.04120000397656929
#  0.1355999824627505
