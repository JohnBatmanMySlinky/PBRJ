# %%
include("../RayTracing.jl")
using BenchmarkTools

# %%
RayTracing.lobal_logger(RayTracing.NullLogger())

# %%
it = RayTracing.ImageTexture(
    RayTracing.UVMapping2D(4.0, 1.5, 0.0, 0.0),
    RayTracing.jmfp("/home/jmyslinski/random_stuff/PBRJ/ref/elevator_wood_1_albedo.png"),
    false
)
# Out:
# ┌ Info: Resampling MIPMap from [640, 640] to [1024, 1024]. Ratio = 2.56
# └ @ Main.RayTracing /home/jmyslinski/random_stuff/PBRJ/src/mip_map.jl:49
# ┌ Info: Original Image 1 [0.3215686274509804, 0.3215686274509804, 0.3215686274509804]
# └ @ Main.RayTracing /home/jmyslinski/random_stuff/PBRJ/src/mip_map.jl:52
# ┌ Info: Original Image 2 [0.2980392156862745, 0.2980392156862745, 0.2980392156862745]
# └ @ Main.RayTracing /home/jmyslinski/random_stuff/PBRJ/src/mip_map.jl:52
# ┌ Info: Original Image 3 [0.3215686274509804, 0.3215686274509804, 0.3215686274509804]
# └ @ Main.RayTracing /home/jmyslinski/random_stuff/PBRJ/src/mip_map.jl:52
# ┌ Info: Original Image 4 [0.3215686274509804, 0.3215686274509804, 0.3215686274509804]
# └ @ Main.RayTracing /home/jmyslinski/random_stuff/PBRJ/src/mip_map.jl:52
# ┌ Info: Original Image 5 [0.3215686274509804, 0.3215686274509804, 0.3215686274509804]
# └ @ Main.RayTracing /home/jmyslinski/random_stuff/PBRJ/src/mip_map.jl:52
# ...
