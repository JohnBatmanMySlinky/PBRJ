# %%
using Images
using Random

# Set a specific seed for reproducibility
function create_colorful_grid(seed, N)
    # Set the random seed
    Random.seed!(seed)
    
    # Initialize a 10x10 RGB image
    img = zeros(RGB{N0f8}, N, N)
    
    # Fill each pixel with a different random color
    for i in 1:N
        for j in 1:N
            # Generate random RGB values (0-1 for Julia's RGB type)
            r = rand()
            g = rand()
            b = rand()
            
            # Set pixel color
            img[i, j] = RGB(r, g, b)
        end
    end
    
    # Save the image
    save("colorful_grid_seed_$(seed)_$(N)x$(N).png", img)
    
    return img
end

# Create and display the image with a specific seed
colorful_grid = create_colorful_grid(42, 10)  # Using seed value 42

# To create another image with the same pattern, use the same seed
# colorful_grid_same = create_colorful_grid(42)  # Will be identical

# To create a different pattern, use a different seed
# colorful_grid_different = create_colorful_grid(100)  # Different pattern
# Out:
# 10×10 Array{RGB{N0f8},2} with eltype RGB{N0f8}:
#  RGB{N0f8}(0.627,0.451,0.478)  …  RGB{N0f8}(0.859,0.322,0.565)
#  RGB{N0f8}(0.322,0.157,0.722)     RGB{N0f8}(0.835,0.953,0.22)
#  RGB{N0f8}(0.655,0.282,0.365)     RGB{N0f8}(0.086,0.702,0.557)
#  RGB{N0f8}(0.298,0.533,0.835)     RGB{N0f8}(0.643,0.286,0.357)
#  RGB{N0f8}(0.592,0.337,0.259)     RGB{N0f8}(0.82,0.067,0.502)
#  RGB{N0f8}(0.51,0.345,1.0)     …  RGB{N0f8}(0.945,0.639,0.737)
#  RGB{N0f8}(0.11,0.133,0.859)      RGB{N0f8}(0.78,0.031,0.4)
#  RGB{N0f8}(0.859,0.914,0.569)     RGB{N0f8}(0.549,0.169,0.216)
#  RGB{N0f8}(0.624,0.769,0.216)     RGB{N0f8}(0.612,0.565,0.945)
#  RGB{N0f8}(0.133,0.145,0.733)     RGB{N0f8}(0.882,0.282,0.812)
