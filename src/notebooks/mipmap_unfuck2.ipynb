# %%
include("../RayTracing.jl")
# Out:
# Main.RayTracing

# %%
logger = RayTracing.setup_logging(false)
RayTracing.global_logger(logger)
# Out:
# Base.CoreLogging.SimpleLogger(VSCodeServer.IJuliaCore.IJuliaStdio{Base.PipeEndpoint, typeof(VSCodeServer.io_send_callback)}(IOContext(Base.PipeEndpoint(RawFD(20) open, 0 bytes waiting)), VSCodeServer.io_send_callback), Info, Dict{Any, Int64}())

# %%
it = RayTracing.ImageTexture(
    # 800 x 590
    RayTracing.UVMapping2D(1.0, 1.0, 0.0, 0.0), 
    # jmfp("/Users/johnmyslinski/Documents/pbrt-v3-scenes/barcelona-pavilion/textures/rocks.png"),
    RayTracing.jmfp("/Users/johnmyslinski/Documents/PBRJ/src/notebooks/colorful_grid_seed_42_5x5.png"),
    false
)
# Out:
# Main.RayTracing.ImageTexture{Main.RayTracing.Spectrum}(Main.RayTracing.UVMapping2D(1.0, 1.0, 0.0, 0.0), Main.RayTracing.MIPMap{Main.RayTracing.Spectrum}(false, 8.0, 1, [8, 8], Matrix{Main.RayTracing.Spectrum}[[[0.6640695013155478, 0.44734035363375174, 0.5251525793547863] [0.371666043266869, 0.36386327187264395, 0.3447595595113769] … [0.8369889527650223, 0.29665654961517773, 0.5218511461466069] [0.6116104961251716, 0.24522159660373424, 0.3068777815487335]; [0.6968810452087485, 0.5593180839975693, 0.3458254221204539] [0.47282061378887175, 0.4905784170731293, 0.22501832565653587] … [0.8585031331223302, 0.5000422227710347, 0.5333565684756671] [0.7499542018528595, 0.48692069489731976, 0.5329640440878827]; … ; [0.2804072158526525, 0.44353294600307014, 0.5844735616779669] [0.46160230164803717, 0.38878768497145977, 0.5530108192585415] … [0.759586221983214, 0.6136636161278965, 0.2781901227904317] [0.8662896238119033, 0.6271941351669156, 0.42551139736531274]; [0.3027383906265748, 0.23012769721938706, 0.5034002705310618] [0.577927306857337, 0.2818654913389645, 0.5512466087603372] … [0.7662654034991896, 0.9509186791992774, 0.10721300996291971] [0.6766347410813434, 0.8103245397793002, 0.0050532257072098226]], [[0.5513593008950093, 0.4652750316442736, 0.3601889716607882] [0.170305877083135, 0.22702290122185637, 0.3143472319382111] [0.7388575952814117, 0.29027043517758144, 0.6503409853648128] [0.7642641959663459, 0.3822102659718166, 0.47376238506472257]; [0.6458432752452705, 0.6303571038031199, 0.2625550691257144] [0.47590122285969283, 0.28252816011624066, 0.2897960163862427] [0.5531400560935195, 0.45796609392666376, 0.3756371327646286] [0.6308095906688687, 0.49072732511752487, 0.4818135270593386]; [0.41751837207222264, 0.5959395408417707, 0.5727426850412272] [0.400343441972913, 0.3665567085085153, 0.5550174088634983] [0.3018663165760432, 0.37339004755591804, 0.4039662623848649] [0.6445658010480024, 0.20805779693993975, 0.5052479084379137]; [0.4056688037461504, 0.33607845488322036, 0.5480328150569769] [0.7672594668590337, 0.2657610723764996, 0.46095428522635745] [0.7362373888229463, 0.5798511967845601, 0.2243497404149305] [0.7671939975939125, 0.7505252425683475, 0.2039919389564685]], [[0.4608524190207769, 0.4012957991963726, 0.3067218222777391] [0.6717678595025365, 0.4052935300483967, 0.49538850756337566]; [0.4976975211625799, 0.3910839441525015, 0.5341867985470149] [0.6124658760102261, 0.47795607096219134, 0.33438896254854433]], [[0.5606959189240298, 0.4189073360898655, 0.4176715227341685];;]], Main.RayTracing.Pnt2i[[8, 8], [4, 4], [2, 2], [1, 1]], [0.0, -1.1197106036232398, -1.1043300546228876, -1.0891898217729434, -1.0742861502105516, -1.059615343741385, -1.0451737639229692, -1.030957829162327, -1.0169640138277243, -1.0031888473742936  …  -0.2912778164346931, -0.2888412643153753, -0.28644278254228317, -0.2840817762784541, -0.28175765998106256, -0.279469857256202, -0.2772178007159359, -0.2750009318375827, -0.2728187008251986, -0.2706705664732254]), Main.RayTracing.TexInfo("/Users/johnmyslinski/Documents/PBRJ/src/notebooks/colorful_grid_seed_42_5x5.png", false, 8.0, 1, 1.0, false), 0)

# %%
st = RayTracing.Pnt2(8.92245102, 3.20262933)
dst0 = RayTracing.Vec2(0, 0)
dst1 = RayTracing.Vec2(0, 0)
maximum(abs.(RayTracing.lookup(it.mipmap, st, dst0, dst1) - RayTracing.spectrum_from_float(0.6766347410813434, 0.8103245397793002, 0.005053225707209823))) < 1e-4
# Out:
# true

# %%
st = RayTracing.Pnt2(-3.3501358, -0.849808991)
dst0 = RayTracing.Vec2(0, 0)
dst1 = RayTracing.Vec2(0, 0)
maximum(abs.(RayTracing.lookup(it.mipmap, st, dst0, dst1) - RayTracing.spectrum_from_float(0.664069653, 0.447340399, 0.525152683))) < 1e-4
# Out:
# true

# %%
st = RayTracing.Pnt2(5.0619669, -1.28669941)
dst0 = RayTracing.Vec2(0, 0)
dst1 = RayTracing.Vec2(0, 0)
maximum(abs.(RayTracing.lookup(it.mipmap, st, dst0, dst1) - RayTracing.spectrum_from_float(0.302738369, 0.230127692, 0.503400266))) < 1e-4
# Out:
# true

# %%
st = RayTracing.Pnt2(2.4814024, 6.53813887)
dst0 = RayTracing.Vec2(0, 0)
dst1 = RayTracing.Vec2(0, 0)
maximum(abs.(RayTracing.lookup(it.mipmap, st, dst0, dst1) - RayTracing.spectrum_from_float(0.676634729, 0.81032443, 0.0050532259))) < 1e-4
# Out:
# true

# %%
st = RayTracing.Pnt2(8.45602512, 1.9769733)
dst0 = RayTracing.Vec2(0, 0)
dst1 = RayTracing.Vec2(0, 0)
maximum(abs.(RayTracing.lookup(it.mipmap, st, dst0, dst1) - RayTracing.spectrum_from_float(0.676634789, 0.81032443, 0.0050532259))) < 1e-4
# Out:
# true

# %%
st = RayTracing.Pnt2(6.3449707, -2.34109831)
dst0 = RayTracing.Vec2(0, 0)
dst1 = RayTracing.Vec2(0, 0)
maximum(abs.(RayTracing.lookup(it.mipmap, st, dst0, dst1) - RayTracing.spectrum_from_float(0.302738369, 0.230127707, 0.503400266))) < 1e-4
# Out:
# true

# %%
st = RayTracing.Pnt2(-3.58216214, 2.23785377)
dst0 = RayTracing.Vec2(0, 0)
dst1 = RayTracing.Vec2(0, 0)
maximum(abs.(RayTracing.lookup(it.mipmap, st, dst0, dst1) - RayTracing.spectrum_from_float(0.611610532, 0.245221585, 0.306877792))) < 1e-4
# Out:
# true

# %% [markdown]
# # now with vecs

# %%
st = RayTracing.Pnt2(9.74467278, 0.915937901)
dst0 = RayTracing.Vec2(0.0278649889, -0.0494074598)
dst1 = RayTracing.Vec2(-0.149037525, -0.137862757)
maximum(abs.(RayTracing.lookup(it.mipmap, st, dst0, dst1) - RayTracing.spectrum_from_float(0.692095697, 0.834576488, 0.0226754602))) < 1e-4
# Out:
# MethodError: no method matching EWA(::Int64, ::Main.RayTracing.Pnt2, ::Main.RayTracing.Vec2, ::Main.RayTracing.Vec2)
#
#
#
# Stacktrace:
#
#  [1] lookup(mip_map::Main.RayTracing.MIPMap{Main.RayTracing.Spectrum}, st::Main.RayTracing.Pnt2, dst0::Main.RayTracing.Vec2, dst1::Main.RayTracing.Vec2)
#
#    @ Main.RayTracing ~/Documents/PBRJ/src/mip_map.jl:278
#
#  [2] top-level scope
#
#    @ ~/Documents/PBRJ/src/notebooks/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:4
