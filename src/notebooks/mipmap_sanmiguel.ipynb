# %%
include("../RayTracing.jl")
# Out:
# Main.RayTracing

# %%
logger = RayTracing.setup_logging(false)
RayTracing.global_logger(logger)
# Out:
# Base.CoreLogging.SimpleLogger(VSCodeServer.IJuliaCore.IJuliaStdio{Base.PipeEndpoint, typeof(VSCodeServer.io_send_callback)}(IOContext(Base.PipeEndpoint(RawFD(20) open, 0 bytes waiting)), VSCodeServer.io_send_callback), Info, Dict{Any, Int64}())

# %%
path_header = "/Users/johnmyslinski/Documents/pbrt-v3-scenes/sanmiguel/"

# materials
println("LOADING MATERIALS")
mat_jardinera_1 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/jardinera_1_color.png"),
        false
    ),
    RayTracing.ConstantTexture(0.0),
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/jardinera_1_displacement_2.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.001)
    )
)
mat_moldura_detalle_escalera = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/cantera_naranja_liso.png"),
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_moldura_techo_arcos = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/moldura_volado.png"),
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_moldura_techo = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/moldura_techo.png"),
        false
    ),
    RayTracing.ConstantTexture(0.0),
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/moldura_techo_bump.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.001)
    )
)
mat_escalera = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/escalera_color.png"),
        false
    ),
    RayTracing.ConstantTexture(0.0),
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/escalera_bump.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.001)
    )
)
mat_muros = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/pared_barro_afinado.png"),
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_techos = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/techo.png"),
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_vigas_concreto = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/concreto_02.png"),
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_moldura_volado = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/moldura_volado.png"),
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_losa_volados = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/losa.png"),
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_moldura_2_piso = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/moldura2piso_color.png"),
        false
    ),
    RayTracing.ConstantTexture(0.0),
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/moldura2piso_bump.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.003)
    )
)
mat_piso_interior = RayTracing.Matte(
    RayTracing.ConstantTexture(RayTracing.spectrum_from_float(0.75, 0.75, 0.75)),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_azotea = RayTracing.Matte(
    RayTracing.ConstantTexture(RayTracing.spectrum_from_float(0.54902, 0.54902, 0.54902)),
    RayTracing.ConstantTexture(0.0),
    nothing
)
piso_pasillos_arriba = RayTracing.RayTracing.Plastic(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/piso_rustico.png"), 
        false
    ),
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/piso_rustico_Spec.png"), 
            false
        ),
        RayTracing.ConstantTexture(RayTracing.spectrum_from_float(1.0, 1.0, 1.0))
    ),
    RayTracing.ConstantTexture(0.005),
    nothing,
    nothing,
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/piso_rustico_displace2.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.012)
    ),
    true
)
mat_puerta_arco = RayTracing.Plastic(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/madera_triplay_01.png"), 
        false
    ),
    RayTracing.ConstantTexture(RayTracing.spectrum_from_float(0.113726, 0.113726, 0.113726)),
    RayTracing.ConstantTexture(0.01),
    nothing,
    nothing,
    nothing,
    true
)
mat_barandal_postes = RayTracing.Plastic(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/rust_a1.png"), 
        false
    ),
    RayTracing.ConstantTexture(RayTracing.spectrum_from_float(0.0, 0.0, 0.0)),
    RayTracing.ConstantTexture(0.0),
    nothing,
    nothing,
    nothing,
    true
)
mat_pared_sanMiguel_b = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/muros_a.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pared_sanMiguel_b1 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/muros_b1.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/muros_b1.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.001)
    )
)
mat_pared_sanMiguel_c2 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/muros_c2.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pared_sanMiguel_f = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/muros_f.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pared_sanMiguel_e = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/muros_e.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pared_sanMiguel_d = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/muros_d.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pared_sanMiguel_g = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/muros_g.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pared_sanMiguel_h = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/muros_h.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pared_sanMiguel_i = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/muros_l.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pared_sanMiguel_j = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/muros_j.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_muro_naranja_escalera = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/muros_l.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pared_sanMiguel_m = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/muros_m.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pared_sanMiguel_n = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/muros_n.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pared_sanMiguel_a = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/muros_b.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pared_sanMiguel_p2 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/muros_p_.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pared_sanMiguel_q = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/muros_q3.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pared_sanMiguel_q2 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/muros_q.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pared_sanMiguel_q4 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/muros_q4.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_techo_vigas = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/techo.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_ared_sanMiguel_qpatio = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/muros_q_patio2.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_banqueta = RayTracing.Matte(
    RayTracing.ConstantTexture(RayTracing.spectrum_from_float(0.54902, 0.54902, 0.54902)),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_tierra = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/052terresable.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_arcos_lisos_2 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/arcos_lisos_2_color.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/arcos_lisos_2_bump.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.015)
    )
)
mat_arcos_lisos_3 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/arcos_lisos_3_color_1.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/arcos_lisos_3_bump_1.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.015)
    )
)
mat_pared_sanMiguel_b2 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/muros_b2.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_vigas_techo_b = RayTracing.Plastic(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/madera_rustica_2.png"), 
        false
    ),
    RayTracing.ConstantTexture(RayTracing.spectrum_from_float(0.0431373, 0.0431373, 0.0431373)),
    RayTracing.ConstantTexture(0.01),
    nothing,
    nothing,
    nothing,
    true
)
mat_vigas_techo_a = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/madera_rustica_2.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
) 
mat_pared_sanMiguel_k = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/muros_k.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_piso_patio_exterior_concreto = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/concreto_01.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_vigas_volados = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/Vigas_A2.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/vigas_a2_bump.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.001)
    )
)
mat_techos_2 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/techo_01.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_piso_patio_exterior = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/piso_patio_exterior.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/piso_patio_exterior_displace_inv.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.02)
    )
)
mat_calle = RayTracing.Matte(
    RayTracing.ConstantTexture(RayTracing.spectrum_from_float(0.54902, 0.54902, 0.54902)),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_arco_frente = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/arco_frente.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/arco_frente_displace_inv.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.002)
    )
)
mat_puerta_agarradera01 = RayTracing.Plastic(
    RayTracing.ConstantTexture(RayTracing.spectrum_from_float(0.337255, 0.286275, 0.223529)),
    RayTracing.ConstantTexture(RayTracing.spectrum_from_float(0.501961, 0.443137, 0.372549)),
    RayTracing.ConstantTexture(0.1),
    nothing,
    nothing,
    nothing,
    true
)
mat_pintura_15 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/D30_Smiguel_2003_7785.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pintura_1 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/0001_carros.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pintura_2 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/D30_Smiguel_2003_7815.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pintura_3 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/D30_Smiguel_2003_7812.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pintura_12 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/027_Cola Caballo 06-30-1997.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pintura_5 = RayTracing.Matte(
    
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/D30_Smiguel_2003_7812.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pintura_6 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/D30_Smiguel_2003_7843.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pintura_7 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/D30_Smiguel_2003_7785.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pintura_8 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/D30_Smiguel_2003_7758.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pintura_9 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/D30_Smiguel_2003_7843.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pintura_10 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/D30_Smiguel_2003_7833.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pintura_11 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/D30_Smiguel_2003_7768.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pintura_4 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/D30_Smiguel_2003_7833.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pintura_13 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/D30_Smiguel_2003_7833.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pintura_14 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/D30_Smiguel_2003_7833.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_pintura_marcos = RayTracing.Plastic(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/madera_marcos.png"), 
        false
    ),
    RayTracing.ConstantTexture(RayTracing.spectrum_from_float(0.156863, 0.156863, 0.156863)),
    RayTracing.ConstantTexture(0.001),
    nothing,
    nothing,
    nothing,
    true
)
mat_postes_barandal = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/postes_barandal_color.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/postes_barandal_bump.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.015)
    )
)
mat_piso_patio_exterior2 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/piso_patio_exterior2.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_sun_light = RayTracing.Matte(
    RayTracing.ConstantTexture(RayTracing.spectrum_from_float(5.0, 4.1960802078, 2.4509799480)),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_madera_barandal = RayTracing.Plastic(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/madera_barandal_esc_2.png"), 
        false
    ),
    RayTracing.ConstantTexture(RayTracing.spectrum_from_float(0.0, 0.0, 0.0)),
    RayTracing.ConstantTexture(0.1),
    nothing,
    nothing,
    nothing,
    true
)
mat_pared_calle = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/pared_calle.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_candil_2_foco = RayTracing.Glass(
    RayTracing.ConstantTexture(RayTracing.spectrum_from_float(1.0, 1.0, 1.0)),
    RayTracing.ConstantTexture(RayTracing.spectrum_from_float(1.0, 1.0, 1.0)),
    RayTracing.ConstantTexture(0.0),
    RayTracing.ConstantTexture(0.0),
    RayTracing.ConstantTexture(1.5),
    nothing,
    true
)
mat_detMoldura_06 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/detmoldura_06_color.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/detmoldura_06_bump.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.01)
    )
)
mat_detMoldura_05 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/detmoldura_05_color.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/detmoldura_05_bump.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.01)
    )
)
mat_detMoldura_04 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/detmoldura_04_color.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/detmoldura_04_bump.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.01)
    )
)
mat_detMoldura_03 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/detmoldura_03_color.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/detmoldura_03_bump.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.01)
    )
)
mat_detMoldura_02 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/detmoldura_02_color.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/detmoldura_02_bump.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.01)
    )
)
mat_detMoldura_01 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/detmoldura_01_color.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/detmoldura_01_bump.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.01)
    )
)
mat_detalle_escalera = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/rust_a1.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_marco_puerta_1 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/marco_puerta_1.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/marco_puerta_1_bump.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.01)
    )
)
mat_marco_puerta = RayTracing.Plastic(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/madera_barandal_esc_2.png"), 
        false
    ),
    RayTracing.ConstantTexture(RayTracing.spectrum_from_float(0.0, 0.0, 0.0)),
    RayTracing.ConstantTexture(0.1),
    nothing,
    nothing,
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/madera_barandal_esc_2_bump.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.001)
    ),
    true
)
mat_mold_arco_01 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/mold_arco_01_color.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/mold_arco_01_bump.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.001)
    )
)
mat_mold_terraza = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/molduraterraza__color.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/molduraterraza_bump.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.001)
    )
)
mat_puerta_agarradera = RayTracing.Matte(
    RayTracing.ConstantTexture(RayTracing.spectrum_from_float(0.392157, 0.368627, 0.341176)),
    RayTracing.ConstantTexture(0.0),
    nothing
)
mat_puerta_arco = RayTracing.Plastic(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/madera_triplay_01.png"), 
        false
    ),
    RayTracing.ConstantTexture(RayTracing.spectrum_from_float(0.113726, 0.113726, 0.113726)),
    RayTracing.ConstantTexture(0.01),
    nothing,
    nothing,
    nothing,
    true
)
mat_puerta_01 = RayTracing.Plastic(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/puerta.png"), 
        false
    ),
    RayTracing.ConstantTexture(RayTracing.spectrum_from_float(0.0431373, 0.0431373, 0.0431373)),
    RayTracing.ConstantTexture(0.1),
    nothing,
    nothing,
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/puerta_bump.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.001)
    ),
    true,
)
mat_columna_a1 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/columna_a_color.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/columna_a_displacement_3_inv.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.001)
    )
)
mat_columna_a2 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/columna_a_color_2.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/columna_a_displacement_3_inv.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.001)
    )
)
mat_columna_a3 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/columna_a_color_3.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/columna_a_displacement_3_inv.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.001)
    )
)
mat_columna_b1 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/columna_b_color.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/columna_b_displacement_3_inv.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.015)
    )
)
mat_columna_b3 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/columna_b_color_3.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/columna_b_displacement_3_inv.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.015)
    )
)
mat_columna_b2 = RayTracing.Matte(
    RayTracing.ImageTexture(
        RayTracing.UVMapping2D(),
        RayTracing.jmfp(path_header * "textures/columna_b_color_2.png"), 
        false
    ),
    RayTracing.ConstantTexture(0.0),
    RayTracing.MixMultTexture(
        RayTracing.ImageTexture(
            RayTracing.UVMapping2D(),
            RayTracing.jmfp(path_header * "textures/columna_b_displacement_3_inv.png"), 
            true
        ),
        RayTracing.ConstantTexture(0.015)
    )
)
# Out:
# LOADING MATERIALS
# ...

# %%
mat_dict = Dict{String, RayTracing.Material}()

mat_dict["sanmiguel_00001_ascii.obj"] = mat_vidrio
mat_dict["sanmiguel_00073_ascii.obj"] = mat_vidrio

mat_dict["sanmiguel_00002_ascii.obj"] = mat_jardinera_1
mat_dict["sanmiguel_00003_ascii.obj"] = mat_jardinera_1

mat_dict["sanmiguel_00004_ascii.obj"] = mat_moldura_detalle_escalera

mat_dict["sanmiguel_00005_ascii.obj"] = mat_moldura_techo_arcos

mat_dict["sanmiguel_00006_ascii.obj"] = mat_moldura_techo

mat_dict["sanmiguel_00007_ascii.obj"] = mat_escalera

mat_dict["sanmiguel_00008_ascii.obj"] = mat_muros
mat_dict["sanmiguel_00037_ascii.obj"] = mat_muros
mat_dict["sanmiguel_00041_ascii.obj"] = mat_muros

mat_dict["sanmiguel_00009_ascii.obj"] = mat_techos

mat_dict["sanmiguel_00010_ascii.obj"] = mat_vigas_concreto

mat_dict["sanmiguel_00011_ascii.obj"] = mat_moldura_volado

mat_dict["sanmiguel_00012_ascii.obj"] = mat_losa_volados

mat_dict["sanmiguel_00013_ascii.obj"] = mat_moldura_2_piso

mat_dict["sanmiguel_00014_ascii.obj"] = mat_piso_interior
mat_dict["sanmiguel_00016_ascii.obj"] = mat_piso_interior
mat_dict["sanmiguel_00018_ascii.obj"] = mat_piso_interior

mat_dict["sanmiguel_00015_ascii.obj"] = mat_azotea

mat_dict["sanmiguel_00017_ascii.obj"] = piso_pasillos_arriba
mat_dict["sanmiguel_00055_ascii.obj"] = piso_pasillos_arriba

mat_dict["sanmiguel_00019_ascii.obj"] = mat_puerta_arco
mat_dict["sanmiguel_00020_ascii.obj"] = mat_puerta_arco
mat_dict["sanmiguel_00201_ascii.obj"] = mat_puerta_arco
mat_dict["sanmiguel_00202_ascii.obj"] = mat_puerta_arco

mat_dict["sanmiguel_00021_ascii.obj"] = mat_barandal_postes

mat_dict["sanmiguel_00022_ascii.obj"] = mat_pared_sanMiguel_b

mat_dict["sanmiguel_00023_ascii.obj"] = mat_pared_sanMiguel_b1

mat_dict["sanmiguel_00024_ascii.obj"] = mat_pared_sanMiguel_c2

mat_dict["sanmiguel_00025_ascii.obj"] = mat_pared_sanMiguel_f

mat_dict["sanmiguel_00026_ascii.obj"] = mat_pared_sanMiguel_e

mat_dict["sanmiguel_00027_ascii.obj"] = mat_pared_sanMiguel_d

mat_dict["sanmiguel_00028_ascii.obj"] = mat_pared_sanMiguel_g

mat_dict["sanmiguel_00029_ascii.obj"] = mat_pared_sanMiguel_h

mat_dict["sanmiguel_00030_ascii.obj"] = mat_pared_sanMiguel_i

mat_dict["sanmiguel_00031_ascii.obj"] = mat_pared_sanMiguel_j

mat_dict["sanmiguel_00032_ascii.obj"] = mat_muro_naranja_escalera

mat_dict["sanmiguel_00033_ascii.obj"] = mat_pared_sanMiguel_m

mat_dict["sanmiguel_00034_ascii.obj"] = mat_pared_sanMiguel_n

mat_dict["sanmiguel_00035_ascii.obj"] = mat_pared_sanMiguel_a

mat_dict["sanmiguel_00036_ascii.obj"] = mat_pared_sanMiguel_p2

mat_dict["sanmiguel_00038_ascii.obj"] = mat_pared_sanMiguel_q

mat_dict["sanmiguel_00039_ascii.obj"] = mat_pared_sanMiguel_q2

mat_dict["sanmiguel_00040_ascii.obj"] = mat_pared_sanMiguel_q4

mat_dict["sanmiguel_00042_ascii.obj"] = mat_techo_vigas

mat_dict["sanmiguel_00044_ascii.obj"] = mat_ared_sanMiguel_qpatio

mat_dict["sanmiguel_00045_ascii.obj"] = mat_banqueta

mat_dict["sanmiguel_00046_ascii.obj"] = mat_tierra
mat_dict["sanmiguel_00047_ascii.obj"] = mat_tierra

mat_dict["sanmiguel_00048_ascii.obj"] = mat_arcos_lisos_2
mat_dict["sanmiguel_00049_ascii.obj"] = mat_arcos_lisos_2

mat_dict["sanmiguel_00050_ascii.obj"] = mat_arcos_lisos_3

mat_dict["sanmiguel_00051_ascii.obj"] = mat_pared_sanMiguel_b2

mat_dict["sanmiguel_00052_ascii.obj"] = mat_vigas_techo_b

mat_dict["sanmiguel_00053_ascii.obj"] = mat_vigas_techo_a

mat_dict["sanmiguel_00054_ascii.obj"] = mat_pared_sanMiguel_k

mat_dict["sanmiguel_00056_ascii.obj"] = mat_piso_patio_exterior_concreto

mat_dict["sanmiguel_00057_ascii.obj"] = mat_vigas_volados

mat_dict["sanmiguel_00058_ascii.obj"] = mat_techos_2

mat_dict["sanmiguel_00059_ascii.obj"] = mat_piso_patio_exterior

mat_dict["sanmiguel_00061_ascii.obj"] = mat_calle

mat_dict["sanmiguel_00062_ascii.obj"] = mat_arco_frente
mat_dict["sanmiguel_00063_ascii.obj"] = mat_arco_frente
mat_dict["sanmiguel_00064_ascii.obj"] = mat_arco_frente
mat_dict["sanmiguel_00065_ascii.obj"] = mat_arco_frente
mat_dict["sanmiguel_00066_ascii.obj"] = mat_arco_frente
mat_dict["sanmiguel_00067_ascii.obj"] = mat_arco_frente
mat_dict["sanmiguel_00068_ascii.obj"] = mat_arco_frente
mat_dict["sanmiguel_00069_ascii.obj"] = mat_arco_frente
mat_dict["sanmiguel_00070_ascii.obj"] = mat_arco_frente
mat_dict["sanmiguel_00071_ascii.obj"] = mat_arco_frente
mat_dict["sanmiguel_00072_ascii.obj"] = mat_arco_frente

mat_dict["sanmiguel_00074_ascii.obj"] = mat_puerta_agarradera01

mat_dict["sanmiguel_00075_ascii.obj"] = mat_pintura_15

mat_dict["sanmiguel_00076_ascii.obj"] = mat_pintura_1

mat_dict["sanmiguel_00077_ascii.obj"] = mat_pintura_2

mat_dict["sanmiguel_00078_ascii.obj"] = mat_pintura_3
mat_dict["sanmiguel_00090_ascii.obj"] = mat_pintura_3
mat_dict["sanmiguel_00091_ascii.obj"] = mat_pintura_3
mat_dict["sanmiguel_00092_ascii.obj"] = mat_pintura_3
mat_dict["sanmiguel_00093_ascii.obj"] = mat_pintura_3
mat_dict["sanmiguel_00094_ascii.obj"] = mat_pintura_3
mat_dict["sanmiguel_00095_ascii.obj"] = mat_pintura_3
mat_dict["sanmiguel_00096_ascii.obj"] = mat_pintura_3
mat_dict["sanmiguel_00097_ascii.obj"] = mat_pintura_3
mat_dict["sanmiguel_00098_ascii.obj"] = mat_pintura_3
mat_dict["sanmiguel_00099_ascii.obj"] = mat_pintura_3
mat_dict["sanmiguel_00100_ascii.obj"] = mat_pintura_3
mat_dict["sanmiguel_00101_ascii.obj"] = mat_pintura_3
mat_dict["sanmiguel_00102_ascii.obj"] = mat_pintura_3
mat_dict["sanmiguel_00103_ascii.obj"] = mat_pintura_3
mat_dict["sanmiguel_00104_ascii.obj"] = mat_pintura_3
mat_dict["sanmiguel_00105_ascii.obj"] = mat_pintura_3
mat_dict["sanmiguel_00106_ascii.obj"] = mat_pintura_3
mat_dict["sanmiguel_00107_ascii.obj"] = mat_pintura_3
mat_dict["sanmiguel_00108_ascii.obj"] = mat_pintura_3
mat_dict["sanmiguel_00109_ascii.obj"] = mat_pintura_3
mat_dict["sanmiguel_00110_ascii.obj"] = mat_pintura_3
mat_dict["sanmiguel_00111_ascii.obj"] = mat_pintura_3
mat_dict["sanmiguel_00112_ascii.obj"] = mat_pintura_3
mat_dict["sanmiguel_00113_ascii.obj"] = mat_pintura_3
mat_dict["sanmiguel_00114_ascii.obj"] = mat_pintura_3

mat_dict["sanmiguel_00079_ascii.obj"] = mat_pintura_12

mat_dict["sanmiguel_00080_ascii.obj"] = mat_pintura_5

mat_dict["sanmiguel_00081_ascii.obj"] = mat_pintura_6

mat_dict["sanmiguel_00082_ascii.obj"] = mat_pintura_7

mat_dict["sanmiguel_00083_ascii.obj"] = mat_pintura_8

mat_dict["sanmiguel_00084_ascii.obj"] = mat_pintura_9

mat_dict["sanmiguel_00085_ascii.obj"] = mat_pintura_10

mat_dict["sanmiguel_00086_ascii.obj"] = mat_pintura_11

mat_dict["sanmiguel_00087_ascii.obj"] = mat_pintura_4

mat_dict["sanmiguel_00088_ascii.obj"] = mat_pintura_13

mat_dict["sanmiguel_00089_ascii.obj"] = mat_pintura_14

mat_dict["sanmiguel_00115_ascii.obj"] = mat_pintura_marcos
mat_dict["sanmiguel_00116_ascii.obj"] = mat_pintura_marcos
mat_dict["sanmiguel_00117_ascii.obj"] = mat_pintura_marcos
mat_dict["sanmiguel_00118_ascii.obj"] = mat_pintura_marcos
mat_dict["sanmiguel_00119_ascii.obj"] = mat_pintura_marcos
mat_dict["sanmiguel_00120_ascii.obj"] = mat_pintura_marcos
mat_dict["sanmiguel_00121_ascii.obj"] = mat_pintura_marcos
mat_dict["sanmiguel_00122_ascii.obj"] = mat_pintura_marcos
mat_dict["sanmiguel_00123_ascii.obj"] = mat_pintura_marcos
mat_dict["sanmiguel_00124_ascii.obj"] = mat_pintura_marcos
mat_dict["sanmiguel_00125_ascii.obj"] = mat_pintura_marcos
mat_dict["sanmiguel_00126_ascii.obj"] = mat_pintura_marcos
mat_dict["sanmiguel_00127_ascii.obj"] = mat_pintura_marcos
mat_dict["sanmiguel_00128_ascii.obj"] = mat_pintura_marcos
mat_dict["sanmiguel_00129_ascii.obj"] = mat_pintura_marcos

mat_dict["sanmiguel_00130_ascii.obj"] = mat_postes_barandal

mat_dict["sanmiguel_00132_ascii.obj"] = mat_piso_patio_exterior2

mat_dict["sanmiguel_00133_ascii.obj"] = mat_sun_light

mat_dict["sanmiguel_00140_ascii.obj"] = mat_madera_barandal

mat_dict["sanmiguel_00142_ascii.obj"] = mat_pared_calle

mat_dict["sanmiguel_00156_ascii.obj"] = mat_candil_2_foco

mat_dict["sanmiguel_00160_ascii.obj"] = mat_detMoldura_06

mat_dict["sanmiguel_00161_ascii.obj"] = mat_detMoldura_05

mat_dict["sanmiguel_00162_ascii.obj"] = mat_detMoldura_04

mat_dict["sanmiguel_00163_ascii.obj"] = mat_detMoldura_03

mat_dict["sanmiguel_00164_ascii.obj"] = mat_detMoldura_02

mat_dict["sanmiguel_00165_ascii.obj"] = mat_detMoldura_01

mat_dict["sanmiguel_00168_ascii.obj"] = mat_detalle_escalera
mat_dict["sanmiguel_00170_ascii.obj"] = mat_detalle_escalera

mat_dict["sanmiguel_00174_ascii.obj"] = mat_marco_puerta_1
mat_dict["sanmiguel_00175_ascii.obj"] = mat_marco_puerta_1
mat_dict["sanmiguel_00176_ascii.obj"] = mat_marco_puerta_1
mat_dict["sanmiguel_00177_ascii.obj"] = mat_marco_puerta_1
mat_dict["sanmiguel_00178_ascii.obj"] = mat_marco_puerta_1
mat_dict["sanmiguel_00179_ascii.obj"] = mat_marco_puerta_1
mat_dict["sanmiguel_00180_ascii.obj"] = mat_marco_puerta_1
mat_dict["sanmiguel_00181_ascii.obj"] = mat_marco_puerta_1
mat_dict["sanmiguel_00182_ascii.obj"] = mat_marco_puerta_1
mat_dict["sanmiguel_00183_ascii.obj"] = mat_marco_puerta_1
mat_dict["sanmiguel_00184_ascii.obj"] = mat_marco_puerta_1
mat_dict["sanmiguel_00185_ascii.obj"] = mat_marco_puerta_1
mat_dict["sanmiguel_00186_ascii.obj"] = mat_marco_puerta_1
mat_dict["sanmiguel_00187_ascii.obj"] = mat_marco_puerta_1
mat_dict["sanmiguel_00188_ascii.obj"] = mat_marco_puerta_1
mat_dict["sanmiguel_00189_ascii.obj"] = mat_marco_puerta_1
mat_dict["sanmiguel_00190_ascii.obj"] = mat_marco_puerta_1

mat_dict["sanmiguel_00191_ascii.obj"] = mat_marco_puerta

mat_dict["sanmiguel_00192_ascii.obj"] = mat_mold_arco_01
mat_dict["sanmiguel_00193_ascii.obj"] = mat_mold_arco_01
mat_dict["sanmiguel_00194_ascii.obj"] = mat_mold_arco_01
mat_dict["sanmiguel_00195_ascii.obj"] = mat_mold_arco_01
mat_dict["sanmiguel_00196_ascii.obj"] = mat_mold_arco_01
mat_dict["sanmiguel_00197_ascii.obj"] = mat_mold_arco_01

mat_dict["sanmiguel_00198_ascii.obj"] = mat_mold_terraza
mat_dict["sanmiguel_00199_ascii.obj"] = mat_mold_terraza

mat_dict["sanmiguel_00200_ascii.obj"] = mat_puerta_agarradera

mat_dict["sanmiguel_00201_ascii.obj"] = mat_puerta_arco
mat_dict["sanmiguel_00202_ascii.obj"] = mat_puerta_arco

mat_dict["sanmiguel_00203_ascii.obj"] = mat_puerta_01

mat_dict["sanmiguel_00221_ascii.obj"] = mat_columna_a1
mat_dict["sanmiguel_00224_ascii.obj"] = mat_columna_a1
mat_dict["sanmiguel_00225_ascii.obj"] = mat_columna_a1

mat_dict["sanmiguel_00222_ascii.obj"] = mat_columna_a2
mat_dict["sanmiguel_00231_ascii.obj"] = mat_columna_a2

mat_dict["sanmiguel_00223_ascii.obj"] = mat_columna_a3

mat_dict["sanmiguel_00226_ascii.obj"] = mat_columna_b1
mat_dict["sanmiguel_00229_ascii.obj"] = mat_columna_b1
mat_dict["sanmiguel_00232_ascii.obj"] = mat_columna_b1

mat_dict["sanmiguel_00227_ascii.obj"] = mat_columna_b1

mat_dict["sanmiguel_00227_ascii.obj"] = mat_columna_b3

mat_dict["sanmiguel_00228_ascii.obj"] = mat_columna_b2
mat_dict["sanmiguel_00230_ascii.obj"] = mat_columna_b2

println("\t...DONE: we loaded $(length(keys(mat_dict))) materials")
# Out:
# 	...DONE: we loaded 183 materials

# %%
function minmax_matrix(matrix)

    
    return min_val, max_val
end
# Out:
# minmax_matrix (generic function with 1 method)

# %%
for idx in eachindex(imgtex.mipmap.pyramid)
    println(minmax_matrix(imgtex.mipmap.pyramid[idx]))
end
# Out:
# (0.0, 1.0682658588039313)
# (0.012410767833441774, 1.018301888810837)
# (0.09732313847107996, 0.9718975156795913)
# (0.1543812165817177, 0.9283098206724351)
# (0.2050807915355527, 0.8685885839516128)
# (0.2827288777647997, 0.8044671587214531)
# (0.35408619985360085, 0.6696563923590676)
# (0.43572747377632504, 0.5960779507946788)
# (0.47261165065752186, 0.5490603961368081)
# (0.4785001704460664, 0.536512575055916)
# (0.4829873194828631, 0.5337541231777075)

# %%
for (key, value) in mat_dict
    var = JOHN(typeof(value))
    if var == "kd"
        println("Checking: $key")
        for idx in eachindex(value.Kd.mipmap.pyramid)
            mii, maa = minmax_matrix(value.Kd.mipmap.pyramid[idx])
            @assert !isnan(mii) && !isinf(mii) && !isnan(maa) && !isinf(maa)
        end
        println("\t....PASS")
    elseif var == "bump_mix_1"
        println("Checking: $key")
        for idx in eachindex(value.bump_map.a.mipmap.pyramid)
            mii, maa = minmax_matrix(value.bump_map.a.mipmap.pyramid[idx])
            @assert !isnan(mii) && !isinf(mii) && !isnan(maa) && !isinf(maa)
        end
        println("\t....PASS")
    end
end
# Out:
# Checking: sanmiguel_00057_ascii.obj
# 	....PASS
# Checking: sanmiguel_00019_ascii.obj
# 	....PASS
# Checking: sanmiguel_00188_ascii.obj
# 	....PASS
# Checking: sanmiguel_00091_ascii.obj
# 	....PASS
# Checking: sanmiguel_00005_ascii.obj
# 	....PASS
# Checking: sanmiguel_00221_ascii.obj
# 	....PASS
# Checking: sanmiguel_00118_ascii.obj
# 	....PASS
# Checking: sanmiguel_00026_ascii.obj
# 	....PASS
# Checking: sanmiguel_00098_ascii.obj
# 	....PASS
# Checking: sanmiguel_00055_ascii.obj
# 	....PASS
# Checking: sanmiguel_00112_ascii.obj
# 	....PASS
# Checking: sanmiguel_00191_ascii.obj
# 	....PASS
# Checking: sanmiguel_00192_ascii.obj
# 	....PASS
# Checking: sanmiguel_00199_ascii.obj
# 	....PASS
# Checking: sanmiguel_00041_ascii.obj
# 	....PASS
# Checking: sanmiguel_00163_ascii.obj
# 	....PASS
# Checking: sanmiguel_00202_ascii.obj
# 	....PASS
# Checking: sanmiguel_00080_ascii.obj
# 	....PASS
# Checking: sanmiguel_00017_ascii.obj
# 	....PASS
# Checking: sanmiguel_00121_ascii.obj
# 	....PASS
# ...
